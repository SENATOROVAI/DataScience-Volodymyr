# %%
28.02.2024
Познакомился с профессией data scine,узнал как принимать файлы и отправлять их на гит.
Узнал что гит это площадка для коммандной работы + размещения своего кода.
Ознакомился с правилами обучения.
И так расспишу всё по порядку.
Создал респозиторий на гитхабе, это теперь моё окружение где я буду в будущем писать свой код в команде.
Так же мы запинили мой респозиторй + добавили лайк ).
Я присоеденился к команде на гите и теперь могу смотреть работы других разработчиков ( которые находятья в команде), + добавил респазиторий калькулятора к себе в профиль
Далее мы установили дополнение в vs code = share/  для сихнронного показа моего кода учителю, а так же учитель может вносить и делать правки в лайв режиме.
Установили новый python потому что через команду Pip он не оторбражался. + добавили mypy.
Узнал какое действие выполняет кнопка коммит - это фиксация ( подтверждение)
Установили black через pip . для инструмента анализа и поиска ошибок согласно pep8(BLACK)

# %%
Научился создавать виртуальное окружение командой python -m venv venv, виртуальное окружение работает на уровне папки с питоном и его зависимостями.
Так же разобрали как создавать виртуальное окружение через терминал, той же самой командой что и через вс код.
зарегистирвровались на кэгл,добавили одно готовое решение, получил статус Contributor через копирование и отправку одного задания.
Зарегистриорвались на соревнования на код форсе,отправил решение задачи арбуз

# %%
1. List
Описание: List представляет собой генерический тип данных, который используется для определения списка (массива) в Python. 
Пример использования: List[int] - список целых чисел.
2. Dict
Описание: Dict представляет собой генерический тип данных, который используется для определения словаря в Python. Словарь представляет собой структуру данных, состоящую из ключей и соответствующих им значений.
Пример использования: Dict[str, int] - словарь, в котором ключи являются строками, а значения - целыми числами.
  
3. Union
Описание: Union представляет собой генерический тип данных, который представляет собой объединение нескольких типов данных. Переменная или параметр функции, объявленные с использованием Union, могут принимать значения любого из указанных типов.
Пример использования: Union[int, float] - переменная, которая может быть либо целым числом, либо числом с плавающей точкой.
Модуль typing в Python является частью стандартной библиотеки и предоставляет возможность использования генерических типов данных для более точного определения типов в Python коде. Это улучшает читаемость кода, делает его более понятным и позволяет избежать ошибок при работе с типами данных.
Далее мы познакомились с магическими типами данных 
В Python существуют специальные "магические" методы (иногда их называют "магическими типами данных" или "магическими методами"), которые позволяют объектам вести себя как встроенные типы данных и управлять их поведением. Эти методы обладают двойными подчеркиваниями в начале и в конце имени, например __init__, __str__, __add__ и т. д.
Некоторые из наиболее часто используемых "магических" методов в Python включают:
1. __init__(): Конструктор объекта, вызывается при создании нового экземпляра класса.
2. __str__(): Метод, который возвращает строковое представление объекта, используемое функцией str().
3. __repr__(): Метод, который возвращает представление объекта в виде строки для вывода в интерпретаторе Python или при вызове функции repr().
4. __add__(), __sub__(), __mul__(), __truediv__(): Магические методы для перегрузки операторов сложения, вычитания, умножения и деления соответственно.
5. __len__(), __getitem__(), __setitem__(): Методы для перегрузки операторов длины объекта, доступа к элементам и присваивания элементам.
6. __eq__(), __ne__(), __lt__(), __gt__(), __le__(), __ge__(): Магические методы для перегрузки операторов сравнения.
Применение магических методов позволяет пользовательские классы вести себя так, как это ожидается от стандартных типов данных в Python, что позволяет более гибко управлять объектами и их поведением в различных контекстах.

# %%
Сегодня был урок по введению в ООП.
Разобрался как удалять переменную из памяти и что что такое гарбэйдж коллектор, у каждой переменной есть своя область памяти.
познакомился с оператором идентичности is ю
Научился импрортировать cvs из гитхаба, через pd из модуля pandas.
init__py  это дандер инит пай, это автозагрузчкик модулей импортируеться автоматически к модулю, когда видит ключевое слово импорт.
Узнал что class - это контейнер для функции.
Узнал что sys это пакет или папка а пакет это набор модулей,а модуль этофаайл с раширением .py.
Познакомился с f строками . f-string,  интерполяция строки. извлечение из переменной её значения - это интерполяция.
функции в классе называються методами а переменные в классе - это атриббуты классавсе классы наследються от обжект.

# %% [markdown]
# Сегодня мы смотрели class объекта, как в него заходить, смотреть его параметры.
# Любой класс состоит из атрибутов и методов класса.
# Узнал как вызывать метод класса def append(self, x)
# Узнал что неявно все классы наследуються от класса object, и что они передают 1 параметр object по дефолту
# Имя класса + круглые скобки - это создание объекта
# При работе с объектом,в вызываемый метод передаётьться неявно с имя объекта, иначе говоря self

# %% [markdown]
# lesson 6
# Сегодня познакомились с данредметодом init.py
# Если файл init.py появляеться внутри проекта  интрепритатор понимает что это пакет ( набор модулей)
# Превращает каталог в пакет.
# __init__.py - магический файл, (автозагрузчик модулей)
# Вызываеться ( подключаеться) автоматически к модулю, когда в нашем модуле появляеться импорт к модулю из пакета
# Научились импортировать пакеты из других файлов
# from . - это текущая дериктория, имя файла, импортирует название функции , две точки - это уровень папки выше. точка - это дерриктория папки
# from .controller import main - импортирует функцию main
# init . py - там идёт определение функций, классов, переменных , конфигурация пакетов, ИМПОРТЫ,
# Далее мы поговорили об рекурсии
#
# рекурсия - это вызов функции из функции самой себя
# с помощью рекурсии мы можем делать циклы
