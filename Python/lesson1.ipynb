# %% [markdown]
# 1)Форк - это операция клонирования чужого репазитория в свой личный аккаунт гит хаба, для дальнейшего пулл реквеста.
# 2)Пулл реквест - это операция передачи изменений из личного респозитория в форкнутый.
# 3)Коммит - это фиксация.
# 4)Понятие гит - это локальный контроль версий, он знает всё об изменение кода.в vs code 3 строка под лупой.(КЛИЕТ ГИТА)
# 5)Гитхаб - Размещение гита в интернете.
# 6)Линтер -  это инструмент анализа и поиска ошибок согласно pep8(BLACK)
# 7)Mypy - это интсрумент анализа анотации типов.

# %% [markdown]
# Как принять домашку
# 1)Нажимаем на три точки (3 строка)
# 2)Нажимаем три точки( справа), пулл и всё.
# 3) заходим в комиты в вс коде и смотрим изменение

# %% [markdown]
# как отдать домашку
# 1)заходим в три точки ( заполняем название коммита) название коммита должно отрожать что происходит внутри.
# 2)нажали коммит ( фиксация локальная)
# 3)заходим в три точки и нажимаем пушш
# 4) каждое утро когда просыпаюсь, делаю комманду гит пулл
